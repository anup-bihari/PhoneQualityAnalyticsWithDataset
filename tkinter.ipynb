# %%
import tkinter as tk
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
from pandas import DataFrame
import getpass
#print(getpass.getuser())
root=Tk()
root.title('Retail Analytics')
root.configure(bg='#ffffff')
#root.attributes('-fullscreen',True)
s_width = root.winfo_screenwidth()
s_height = root.winfo_screenheight()
root.geometry("%dx%d" % (s_width, s_height))
#root.geometry('1280x720+110+0')
root.state('zoomed')


upr_fr=Frame(root,cursor='arrow',relief=RIDGE,highlightthickness=2,bg='white',bd=2,width=s_width,height=120)
upr_fr.place(x=10,y=-10)

fr1=Frame(root,cursor='arrow',relief=RIDGE,bg='white',bd=2,width=230,height=120)
fr1.place(x=290,y=170)

fr2=Frame(root,cursor='arrow',relief=RIDGE,highlightthickness=2,bg='white',bd=2,width=230,height=120)
fr2.place(x=550,y=170)

fr3=Frame(root,cursor='arrow',relief=RIDGE,highlightthickness=2,bg='white',bd=2,width=230,height=120)
fr3.place(x=800,y=170)

fr4=Frame(root,cursor='arrow',relief=RIDGE,highlightthickness=2,bg='white',bd=2,width=230,height=120)
fr4.place(x=1050,y=170)

fr5=Frame(root,cursor='arrow',relief=RIDGE,highlightthickness=2,bg='white',bd=2,width=500,height=600)
fr5.place(x=350,y=330)

fr6=Frame(root,cursor='arrow',relief=RIDGE,highlightthickness=2,bg='white',bd=2,width=500,height=600)
fr6.place(x=890,y=330)

side_frame=Frame(root,cursor='arrow',relief=RIDGE,highlightthickness=2,bg='#2c343c',bd=2,width=270,height=1080)
side_frame.place(x=-10,y=-100)
Center_side_frame=Frame(root,cursor='arrow',relief=RIDGE,highlightthickness=2,bg='#2c343c',bd=2,width=270,height=1080)
side_frame.place(x=-20,y=-100)


fr1_Lbl_1=Label(fr1,relief=FLAT,bd=0,bg='white',fg='BLACK',font=("Segoe UI",13),highlightthickness=0,text='Today\'s Woking Hour')
fr1_Lbl_1.place(x=25,y=8)

#fr1_Lbl_1.configure(anchor='center')
fr2_Lbl_1=Label(fr2,relief=FLAT,bd=0,bg='white',fg='BLACK',font=("Segoe UI",13),highlightthickness=0,text='Weekly Woking Hour')
fr2_Lbl_1.place(x=15,y=2)

fr3_Lbl_1=Label(fr3,relief=FLAT,bd=0,bg='white',fg='BLACK',font=("Segoe UI",13),highlightthickness=0,text='Monthly Woking Hour')
fr3_Lbl_1.place(x=10,y=2)

fr4_Lbl_1=Label(fr4,relief=FLAT,bd=0,bg='white',fg='BLACK',font=("Segoe UI",13),highlightthickness=0,text='Shfit Details')
fr4_Lbl_1.place(x=40,y=2)



#upr Frame codes
fr1_Lbl_1=Label(upr_fr,relief=FLAT,bd=0,bg='white',fg='BLACK',font=("Segoe UI",13),highlightthickness=0,text='Hello, %s'%(getpass.getuser()))
fr1_Lbl_1.place(x=s_width-300,y=20)

fr1_Lbl_2=Label(upr_fr,cursor='hand2',relief=RIDGE,bd=0,bg='white',fg='Red',font=("Segoe UI",13),highlightthickness=0,text='Logout')
fr1_Lbl_2.place(x=s_width-150,y=20)

fr1_Lbl_3=Label(upr_fr,relief=FLAT,bd=0,bg='white',fg='BLACK',font=("Segoe UI",20,'bold'),highlightthickness=0,text='Dashboard of Phone Quality')
fr1_Lbl_3.place(x=350,y=50)

# fr1_Lbl_4=Label(upr_fr,relief=FLAT,bd=0,bg='white',fg='BLACK',font=("Segoe UI",13,'italic'),highlightthickness=0,text='MCA Intern')
# fr1_Lbl_4.place(x=550,y=62)

# fr1_Lbl_4=Label(upr_fr,relief=FLAT,bd=0,bg='white',fg='BLACK',font=("Segoe UI",13),highlightthickness=0,text='AnupGaurav@exlservice.com')
# fr1_Lbl_4.place(x=350,y=85)


#define create charts

def create_charts():
    

    data1={'Working_Days':('2020-04-01','2020-04-02','2020-04-03','2020-04-05','2020-04-06'),
          'Production_Hour':[8.33,7.12,6.14,7.99,7.19]}
    
  
    df1 = DataFrame(data1,columns=['Working_Days','Production_Hour'])
    
    
    data2={'Working_Days':('2020-04-01','2020-04-02','2020-04-03','2020-04-05','2020-04-06'),
          'Production_Hour':[8.33,7.12,6.14,7.99,7.19]}
    
    df2 = DataFrame(data2,columns=['Working_Days','Production_Hour'])
    
    
    figure1 = plt.Figure(figsize=(5,4), dpi=100)
    ax1 = figure1.add_subplot(111)
    bar1 = FigureCanvasTkAgg(figure1,fr5)
    bar1.get_tk_widget().pack(side=tk.BOTTOM, fill=tk.BOTH)
    df1 = df1[['Working_Days','Production_Hour']].groupby('Working_Days').sum()
    df1.plot(kind='bar', legend=True, ax=ax1)
    ax1.axhline(y=8,linewidth=2,color='g')
    ax1.set_title('Working_Days Vs. Production_hour')

    
    figure2 = plt.Figure(figsize=(5,4), dpi=100)
    ax2 = figure2.add_subplot(111)
    line2 = FigureCanvasTkAgg(figure2,fr6)
    line2.get_tk_widget().pack(side=tk.RIGHT, fill=tk.BOTH)
    df2 = df2[['Working_Days','Production_Hour']].groupby('Working_Days').sum()
    df2.plot(kind='line', legend=True, ax=ax2, color='r',marker='o', fontsize=10)
    ax2.set_title('Working_Days Vs. Production_hour')


    
#end of define create_charts



#side frAME CODES
fr1_L=Label(side_frame,text='  Employee Time \n Tracking',justify='center',fg='#40E0D0',bg='#2c343c',relief=FLAT,height=2,width=13,font=("Arial",23,'bold'))
fr1_L.place(x=5,y=120)

sfr_Btn_1=Button(side_frame,cursor='hand2',command=create_charts,relief=FLAT,bg='white',height=1,width=23,text='Your Dashboard',font=("Segoe UI",14)) 
sfr_Btn_1.place(x=5,y=350)

sfr_Btn_1=Button(side_frame,cursor='hand2',relief=FLAT,bg='white',height=1,width=23,text='Others Dashboard',font=("Segoe UI",14))
sfr_Btn_1.place(x=1,y=395)

sfr_Btn_1=Button(side_frame,cursor='hand2',relief=FLAT,bg='white',height=1,width=23,text='Send Request',font=("Segoe UI",14))
sfr_Btn_1.place(x=1,y=440)


  
# Resizing image to fit on button 
#photoimage = photo.subsample(3, 3) 
#sfr_Btn_1=Button(side_frame,cursor='hand2',relief=FLAT,bg='white',height=1,width=23, image = photoimage,compound = LEFT,text='Send Request',font=("Segoe UI",14))
#sfr_Btn_1.place(x=1,y=390)

root.mainloop()
